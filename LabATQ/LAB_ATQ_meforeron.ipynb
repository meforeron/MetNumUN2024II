# %% [markdown]
# <a href="https://colab.research.google.com/github/meforeron/MetNumUN2024II/blob/main/LabATQ/LAB_ATQ_meforeron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Q18 Machine Learning Rolling Basis

# %% [markdown]
# # 1. Cambiar técnica de ML
#
# ![Captura de pantalla 2025-01-21 225513.png](data:image/png;base64,...)

# %% [markdown]
# Se uso Random Forest sobre Bayesian Ridge Regression
#
# 1. **Relaciones no lineales:**
#    A diferencia de **Bayesian Ridge Regression**, que solo captura relaciones lineales, **Random Forest** puede identificar patrones más complejos y no lineales.
#
# 2. **Reducción de sobreajuste:**
#    Utilizando múltiples árboles, **Random Forest** reduce el riesgo de sobreajuste al promediar las predicciones, lo que lo hace más robusto ante datos ruidosos.
#
# 3. **Importancia de características:**
#    **Random Forest** identifica automáticamente las características más relevantes para las predicciones, lo que mejora la selección de variables.
#
# En resumen, **Random Forest** es más flexible y robusto, lo que puede llevar a un modelo más preciso en comparación con **Bayesian Ridge Regression**.

# %% [markdown]
# # 2. Cambiar mercado

# %% [markdown]
# El enfoque del mercado se modificó del NASDAQ al S&P 500, ya que este último abarca una muestra más amplia y diversa de las principales empresas de Estados Unidos. Esta decisión permite examinar datos que reflejan de manera más precisa el comportamiento general del mercado.

# %% [markdown]
# # 3. Selección de activos
#
# ![Captura de pantalla 2025-01-21 225944.png](data:image/png;base64,...)

# %% [markdown]
# #### Tecnología:
# - `NAS:AAPL` - Apple
# - `NAS:ADBE` - Adobe
# - `NAS:ADI` - Analog Devices
# - `NAS:ADSK` - Autodesk
# - `NAS:AKAM` - Akamai Technologies
# - `NAS:ALGN` - Align Technology
# - `NAS:AMAT` - Applied Materials
# - `NAS:AMD` - Advanced Micro Devices
# - `NAS:AVGO` - Broadcom
#
# #### Consumo Discrecional:
# - `NAS:ABNB` - Airbnb
# - `NAS:AAL` - American Airlines
# - `NAS:AMZN` - Amazon
#
# #### Energía:
# - `NAS:APA` - APA Corporation
#
# #### Salud:
# - `NAS:AMGN` - Amgen
#
# #### Industria:
# - `NAS:ADP` - Automatic Data Processing
#
# #### Servicios Públicos:
# - `NAS:AEP` - American Electric Power
#
# #### Software de Ingeniería:
# - `NAS:ANSS` - ANSYS

# %% [markdown]
# ### Justificación
#
# 1. **Diversificación:** Cobertura de sectores clave como tecnología, consumo discrecional, energía, salud, e industria para mitigar riesgos.
# 2. **Relevancia:** Empresas líderes como Apple, Amazon y Adobe, con gran impacto en el mercado.
# 3. **Exposición Global:** Empresas con operaciones internacionales significativas.
# 4. **Datos Confiables:** Información histórica bien documentada y accesible para análisis robustos.

# %% [markdown]
# # 4. Nuevas variables
#
# ![Captura de pantalla 2025-01-21 230037.png](data:image/png;base64,...)

# %% [markdown]
# 1. **OBV (On Balance Volume):**
#    Mide la acumulación o distribución de un activo, utilizando el volumen para confirmar la dirección de la tendencia.
#
# 2. **SMA (Simple Moving Average):**
#    Promedia los precios de cierre en un período (20 días en este caso) para identificar la dirección de la tendencia, actuando como soporte o resistencia.
#
# 3. **ATR (Average True Range):**
#    Mide la volatilidad del mercado, ayudando a ajustar estrategias de trading según la amplitud de las fluctuaciones del precio.
#
# Estos indicadores fueron seleccionados para proporcionar una visión completa de la tendencia, el volumen y la volatilidad del mercado.

# %% [markdown]
# # Targets
#
# ![Captura de pantalla 2025-01-21 230504.png](data:image/png;base64,...)

# %% [markdown]
# # Resultados

# %% [markdown]
# ![Captura de pantalla 2025-01-20 174534.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de pantalla 2025-01-29 080419.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de pantalla 2025-01-21 235418.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de pantalla 2025-01-20 174615.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de pantalla 2025-01-20 165519.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de pantalla 2025-01-20 165527.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de pantalla 2025-01-20 165538.png](data:image/png;base64,...)
